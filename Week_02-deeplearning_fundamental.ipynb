# %%
import numpy as np
import pandas as pd
from IPython.display import Image
width = 600; height = 600

# %% [markdown]
# https://www.youtube.com/watch?v=kNPGXgzxoHw

# %%
Image(filename='./img/layer.jpg', width=width, height=height)

# %%
Image(filename='./img/XOR.png', width=width, height=height)

# %%
X = np.array([[0,0], [1,1], [0,1], [1,0]])
X
# Out:
# array([[0, 0],
#        [1, 1],
#        [0, 1],
#        [1, 0]])

# %%
H = np.array([[20, -20], [20, -20]])
H
# Out:
# array([[ 20, -20],
#        [ 20, -20]])

# %%
fully_connected = np.dot(X, H)
layer_output = fully_connected + np.array([-10, 30])
layer_output
# Out:
# array([[-10,  30],
#        [ 30, -10],
#        [ 10,  10],
#        [ 10,  10]])

# %%
np.logical_not(layer_output < 0)*1
# Out:
# array([[0, 1],
#        [1, 0],
#        [1, 1],
#        [1, 1]])
